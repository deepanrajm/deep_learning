# %% [markdown]
# https://drive.google.com/drive/folders/1PNls3aSQ0wQJwh7amkVt2b5uTGYswil5?usp=sharing

# %%
# !git clone https://github.com/st7954/GAN_Deep_Fake_Project
# Out:
# Cloning into 'GAN_Deep_Fake_Project'...
# remote: Enumerating objects: 65, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 65 (delta 1), reused 0 (delta 0), pack-reused 60 (from 1)
# Receiving objects: 100% (65/65), 4.62 MiB | 7.47 MiB/s, done.
# Resolving deltas: 100% (14/14), done.

# %%
cd GAN_Deep_Fake_Project
# Out:
# /content/GAN_Deep_Fake_Project

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
pip install imageio-ffmpeg

# %%
import imageio
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from skimage.transform import resize
from IPython.display import HTML
import warnings
warnings.filterwarnings("ignore")

source_image = imageio.imread('/content/GAN_Deep_Fake_Project/Base_Source_Dataset/Putin_image.png')
reader = imageio.get_reader('/content/GAN_Deep_Fake_Project/Base_Source_Dataset/US_president.mp4')


#Resize image and video to 256x256

source_image = resize(source_image, (256, 256))[..., :3]

fps = reader.get_meta_data()['fps']
driving_video = []
try:
    for im in reader:
        driving_video.append(im)
except RuntimeError:
    pass
reader.close()

driving_video = [resize(frame, (256, 256))[..., :3] for frame in driving_video]

def display(source, driving, generated=None):
    fig = plt.figure(figsize=(8 + 4 * (generated is not None), 6))

    ims = []
    for i in range(len(driving)):
        cols = [source]
        cols.append(driving[i])
        if generated is not None:
            cols.append(generated[i])
        im = plt.imshow(np.concatenate(cols, axis=1), animated=True)
        plt.axis('off')
        ims.append([im])

    ani = animation.ArtistAnimation(fig, ims, interval=50, repeat_delay=1000)
    plt.close()
    return ani


HTML(display(source_image, driving_video).to_html5_video())
# Out:
# <video width="800" height="600" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
from keypointSourceCollector import load_checkpoints
generator, kp_detector = load_checkpoints(config_path='/content/GAN_Deep_Fake_Project/config/vox-256.yaml',
                            checkpoint_path='/content/gdrive/MyDrive/Deep_Fake/vox-cpk.pth.tar')
# Out:
# Skipping
# working

# %%
from denseMotion import make_animation
from skimage import img_as_ubyte

predictions = make_animation(source_image, driving_video, generator, kp_detector, relative=True)

#save resulting video
imageio.mimsave('../generated.mp4', [img_as_ubyte(frame) for frame in predictions], fps=fps)
#video can be downloaded from /content folder

HTML(display(source_image, driving_video, predictions).to_html5_video())
# Out:
# 100%|██████████| 211/211 [00:08<00:00, 23.51it/s]
# <video width="1200" height="600" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
source_image = imageio.imread('/content/GAN_Deep_Fake_Project/Base_Source_Dataset/someone_face.png')
driving_video = imageio.mimread('/content/GAN_Deep_Fake_Project/Base_Source_Dataset/Caprio.mp4', memtest=False)


#Resize image and video to 256x256

source_image = resize(source_image, (256, 256))[..., :3]
driving_video = [resize(frame, (256, 256))[..., :3] for frame in driving_video]

predictions = make_animation(source_image, driving_video, generator, kp_detector, relative=True,
                             adapt_movement_scale=True)

HTML(display(source_image, driving_video, predictions).to_html5_video())
# Out:
# 100%|██████████| 444/444 [00:19<00:00, 22.24it/s]
# <video width="1200" height="600" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
source_image = imageio.imread('//content/gdrive/MyDrive/Deep_Fake/got-04.png')
driving_video = imageio.mimread('/content/gdrive/MyDrive/Deep_Fake/10.mp4', memtest=False)


#Resize image and video to 256x256

source_image = resize(source_image, (256, 256))[..., :3]
driving_video = [resize(frame, (256, 256))[..., :3] for frame in driving_video]

predictions = make_animation(source_image, driving_video, generator, kp_detector, relative=True,
                             adapt_movement_scale=True)

HTML(display(source_image, driving_video, predictions).to_html5_video())
# Out:
# 100%|██████████| 444/444 [00:17<00:00, 25.27it/s]
# <video width="1200" height="600" controls autoplay loop>
#   <source type="video/mp4" src="...
